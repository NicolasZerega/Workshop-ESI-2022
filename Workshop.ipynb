# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\NICOLA~1\AppData\Local\Temp/ipykernel_13328/3217342141.py in <module>
#       1 import pandas as pd
# ----> 2 import cplex
#
# ModuleNotFoundError: No module named 'cplex'

# %%
DtD = pd.read_excel("D_DtD.xlsx")
DtS = pd.read_excel("D_DtS.xlsx")
StS = pd.read_excel("D_StS.xlsx")
P_Ds = pd.read_excel("P_D.xlsx")
Pot_loc = pd.read_excel("Pot_locs.xlsx")
Supplier = pd.read_excel("Supplier.xlsx")

# %%
#Sets
S = {Supplier.ID[i]: {'X':Supplier.X[i],
                      'Y':Supplier.Y[i],
                      'Product_Type':Supplier.Product[i], 
                      'Capacity':Supplier.Prod_Vol[i],
                      'Vehicle':Supplier.V_type[i],
                     } for i in range(len(Supplier))}
W = {Pot_loc.ID[i]:{'X':Pot_loc.X[i],
                   'Y':Pot_loc.Y[i],
                   'Cost':Pot_loc.C[i],
                   'Postal_District':Pot_loc.P_D[i],
                    'Capacity':Pot_loc.Q[i],
                   } for i in range(len(Pot_loc))}
C = {P_Ds.ID[i]:{'Postal_District':P_Ds.P_D[i],
                 'Demand_P1': P_Ds.G1[i],
                 'Demand_P2': P_Ds.G2[i],
                 'Demand_P3': P_Ds.G3[i],
                 'Demand_P4': P_Ds.G4[i],
                } for i in range(len(P_Ds))}

# %%
C
# Out:
# {1: {'Postal_District': 'AB10',
#   'Demand_P1': 6440,
#   'Demand_P2': 10478,
#   'Demand_P3': 10681,
#   'Demand_P4': 3058},
#  2: {'Postal_District': 'AB11',
#   'Demand_P1': 18512,
#   'Demand_P2': 14972,
#   'Demand_P3': 116075,
#   'Demand_P4': 14600},
#  3: {'Postal_District': 'AB12',
#   'Demand_P1': 36700,
#   'Demand_P2': 22866,
#   'Demand_P3': 214693,
#   'Demand_P4': 23418},
#  4: {'Postal_District': 'AB13',
#   'Demand_P1': 4922,
#   'Demand_P2': 912,
#   'Demand_P3': 27032,
#   'Demand_P4': 1082},
#  5: {'Postal_District': 'AB14',
#   'Demand_P1': 5032,
#   'Demand_P2': 2794,
#   'Demand_P3': 33258,
#   'Demand_P4': 4080},
#  6: {'Postal_District': 'AB15',
#   'Demand_P1': 53235,
#   'Demand_P2': 17434,
#   'Demand_P3': 312657,
#   'Demand_P4': 26111},
#  7: {'Postal_District': 'AB16',
#   'Demand_P1': 10770,
#   'Demand_P2': 11513,
#   'Demand_P3': 44224,
#   'Demand_P4': 5958},
#  8: {'Postal_District': 'AB21',
#   'Demand_P1': 10887,
#   'Demand_P2': 8612,
#   'Demand_P3': 53167,
#   'Demand_P4': 5390},
#  9: {'Postal_District': 'AB22',
#   'Demand_P1': 21045,
#   'Demand_P2': 12084,
#   'Demand_P3': 141739,
#   'Demand_P4': 12810},
#  10: {'Postal_District': 'AB23',
#   'Demand_P1': 9235,
#   'Demand_P2': 9247,
#   'Demand_P3': 51161,
#   'Demand_P4': 12570},
#  11: {'Postal_District': 'AB24',
#   'Demand_P1': 47431,
#   'Demand_P2': 39479,
#   'Demand_P3': 483278,
#   'Demand_P4': 31732},
#  12: {'Postal_District': 'AB25',
#   'Demand_P1': 22188,
#   'Demand_P2': 11930,
#   'Demand_P3': 63083,
#   'Demand_P4': 14405},
#  13: {'Postal_District': 'AB30',
#   'Demand_P1': 10091,
#   'Demand_P2': 5578,
#   'Demand_P3': 62968,
#   'Demand_P4': 5057},
#  14: {'Postal_District': 'AB31',
#   'Demand_P1': 15337,
#   'Demand_P2': 11130,
#   'Demand_P3': 95586,
#   'Demand_P4': 8885},
#  15: {'Postal_District': 'AB32',
#   'Demand_P1': 24796,
#   'Demand_P2': 14715,
#   'Demand_P3': 222410,
#   'Demand_P4': 21521},
#  16: {'Postal_District': 'AB33',
#   'Demand_P1': 9394,
#   'Demand_P2': 2810,
#   'Demand_P3': 34895,
#   'Demand_P4': 5080},
#  17: {'Postal_District': 'AB34',
#   'Demand_P1': 3056,
#   'Demand_P2': 3019,
#   'Demand_P3': 16500,
#   'Demand_P4': 3353},
#  18: {'Postal_District': 'AB35',
#   'Demand_P1': 1518,
#   'Demand_P2': 1572,
#   'Demand_P3': 8546,
#   'Demand_P4': 1598},
#  19: {'Postal_District': 'AB36',
#   'Demand_P1': 502,
#   'Demand_P2': 213,
#   'Demand_P3': 1858,
#   'Demand_P4': 123},
#  20: {'Postal_District': 'AB37',
#   'Demand_P1': 1046,
#   'Demand_P2': 1673,
#   'Demand_P3': 6842,
#   'Demand_P4': 2870},
#  21: {'Postal_District': 'AB38',
#   'Demand_P1': 7538,
#   'Demand_P2': 4870,
#   'Demand_P3': 48948,
#   'Demand_P4': 3133},
#  22: {'Postal_District': 'AB39',
#   'Demand_P1': 18876,
#   'Demand_P2': 9755,
#   'Demand_P3': 39342,
#   'Demand_P4': 4647},
#  23: {'Postal_District': 'AB41',
#   'Demand_P1': 28635,
#   'Demand_P2': 12699,
#   'Demand_P3': 169553,
#   'Demand_P4': 15260},
#  24: {'Postal_District': 'AB42',
#   'Demand_P1': 20697,
#   'Demand_P2': 9319,
#   'Demand_P3': 88454,
#   'Demand_P4': 9908},
#  25: {'Postal_District': 'AB43',
#   'Demand_P1': 35404,
#   'Demand_P2': 30723,
#   'Demand_P3': 213599,
#   'Demand_P4': 50804},
#  26: {'Postal_District': 'AB44',
#   'Demand_P1': 4341,
#   'Demand_P2': 2994,
#   'Demand_P3': 29430,
#   'Demand_P4': 4063},
#  27: {'Postal_District': 'AB45',
#   'Demand_P1': 11130,
#   'Demand_P2': 7326,
#   'Demand_P3': 100687,
#   'Demand_P4': 7619},
#  28: {'Postal_District': 'AB51',
#   'Demand_P1': 18844,
#   'Demand_P2': 17658,
#   'Demand_P3': 70580,
#   'Demand_P4': 8292},
#  29: {'Postal_District': 'AB52',
#   'Demand_P1': 10052,
#   'Demand_P2': 2941,
#   'Demand_P3': 67095,
#   'Demand_P4': 5106},
#  30: {'Postal_District': 'AB53',
#   'Demand_P1': 12804,
#   'Demand_P2': 9404,
#   'Demand_P3': 43232,
#   'Demand_P4': 14454},
#  31: {'Postal_District': 'AB54',
#   'Demand_P1': 9171,
#   'Demand_P2': 5364,
#   'Demand_P3': 38431,
#   'Demand_P4': 3996},
#  32: {'Postal_District': 'AB55',
#   'Demand_P1': 11780,
#   'Demand_P2': 6328,
#   'Demand_P3': 60275,
#   'Demand_P4': 5730},
#  33: {'Postal_District': 'AB56',
#   'Demand_P1': 24230,
#   'Demand_P2': 16490,
#   'Demand_P3': 197973,
#   'Demand_P4': 26000},
#  515: {'Postal_District': 'DD1',
#   'Demand_P1': 8729,
#   'Demand_P2': 5408,
#   'Demand_P3': 62490,
#   'Demand_P4': 4436},
#  518: {'Postal_District': 'DD2',
#   'Demand_P1': 41676,
#   'Demand_P2': 23758,
#   'Demand_P3': 162940,
#   'Demand_P4': 46128},
#  519: {'Postal_District': 'DD3',
#   'Demand_P1': 43954,
#   'Demand_P2': 43911,
#   'Demand_P3': 143073,
#   'Demand_P4': 54453},
#  520: {'Postal_District': 'DD4',
#   'Demand_P1': 22609,
#   'Demand_P2': 28884,
#   'Demand_P3': 102049,
#   'Demand_P4': 29979},
#  521: {'Postal_District': 'DD5',
#   'Demand_P1': 22279,
#   'Demand_P2': 29668,
#   'Demand_P3': 157912,
#   'Demand_P4': 50786},
#  522: {'Postal_District': 'DD6',
#   'Demand_P1': 10400,
#   'Demand_P2': 8333,
#   'Demand_P3': 67674,
#   'Demand_P4': 15277},
#  523: {'Postal_District': 'DD7',
#   'Demand_P1': 6768,
#   'Demand_P2': 6289,
#   'Demand_P3': 34658,
#   'Demand_P4': 4295},
#  524: {'Postal_District': 'DD8',
#   'Demand_P1': 35513,
#   'Demand_P2': 22381,
#   'Demand_P3': 299130,
#   'Demand_P4': 25824},
#  525: {'Postal_District': 'DD9',
#   'Demand_P1': 14798,
#   'Demand_P2': 13850,
#   'Demand_P3': 96003,
#   'Demand_P4': 24239},
#  516: {'Postal_District': 'DD10',
#   'Demand_P1': 18730,
#   'Demand_P2': 20678,
#   'Demand_P3': 108975,
#   'Demand_P4': 19797},
#  517: {'Postal_District': 'DD11',
#   'Demand_P1': 23343,
#   'Demand_P2': 25449,
#   'Demand_P3': 129908,
#   'Demand_P4': 49314},
#  549: {'Postal_District': 'DG1',
#   'Demand_P1': 25152,
#   'Demand_P2': 14107,
#   'Demand_P3': 109999,
#   'Demand_P4': 10893},
#  556: {'Postal_District': 'DG2',
#   'Demand_P1': 26727,
#   'Demand_P2': 26177,
#   'Demand_P3': 152697,
#   'Demand_P4': 16586},
#  557: {'Postal_District': 'DG3',
#   'Demand_P1': 3056,
#   'Demand_P2': 1853,
#   'Demand_P3': 10835,
#   'Demand_P4': 1331},
#  558: {'Postal_District': 'DG4',
#   'Demand_P1': 4623,
#   'Demand_P2': 2427,
#   'Demand_P3': 20367,
#   'Demand_P4': 1459},
#  559: {'Postal_District': 'DG5',
#   'Demand_P1': 7827,
#   'Demand_P2': 4819,
#   'Demand_P3': 31741,
#   'Demand_P4': 7978},
#  560: {'Postal_District': 'DG6',
#   'Demand_P1': 10486,
#   'Demand_P2': 6177,
#   'Demand_P3': 79292,
#   'Demand_P4': 4857},
#  561: {'Postal_District': 'DG7',
#   'Demand_P1': 15731,
#   'Demand_P2': 8287,
#   'Demand_P3': 69475,
#   'Demand_P4': 6438},
#  562: {'Postal_District': 'DG8',
#   'Demand_P1': 19332,
#   'Demand_P2': 12507,
#   'Demand_P3': 140211,
#   'Demand_P4': 11192},
#  563: {'Postal_District': 'DG9',
#   'Demand_P1': 28784,
#   'Demand_P2': 18203,
#   'Demand_P3': 244788,
#   'Demand_P4': 32772},
#  550: {'Postal_District': 'DG10',
#   'Demand_P1': 5979,
#   'Demand_P2': 2609,
#   'Demand_P3': 30436,
#   'Demand_P4': 1870},
#  551: {'Postal_District': 'DG11',
#   'Demand_P1': 29001,
#   'Demand_P2': 12734,
#   'Demand_P3': 288231,
#   'Demand_P4': 11199},
#  552: {'Postal_District': 'DG12',
#   'Demand_P1': 13454,
#   'Demand_P2': 12302,
#   'Demand_P3': 89606,
#   'Demand_P4': 7339},
#  553: {'Postal_District': 'DG13',
#   'Demand_P1': 3181,
#   'Demand_P2': 1291,
#   'Demand_P3': 14055,
#   'Demand_P4': 1029},
#  554: {'Postal_District': 'DG14',
#   'Demand_P1': 1396,
#   'Demand_P2': 437,
#   'Demand_P3': 6968,
#   'Demand_P4': 573},
#  689: {'Postal_District': 'EH1',
#   'Demand_P1': 13489,
#   'Demand_P2': 6719,
#   'Demand_P3': 138133,
#   'Demand_P4': 11851},
#  700: {'Postal_District': 'EH2',
#   'Demand_P1': 374,
#   'Demand_P2': 295,
#   'Demand_P3': 816,
#   'Demand_P4': 157},
#  711: {'Postal_District': 'EH3',
#   'Demand_P1': 19567,
#   'Demand_P2': 9804,
#   'Demand_P3': 37002,
#   'Demand_P4': 5038},
#  722: {'Postal_District': 'EH4',
#   'Demand_P1': 32697,
#   'Demand_P2': 20118,
#   'Demand_P3': 117436,
#   'Demand_P4': 18397},
#  733: {'Postal_District': 'EH5',
#   'Demand_P1': 14783,
#   'Demand_P2': 8571,
#   'Demand_P3': 73640,
#   'Demand_P4': 7665},
#  739: {'Postal_District': 'EH6',
#   'Demand_P1': 28384,
#   'Demand_P2': 14027,
#   'Demand_P3': 67489,
#   'Demand_P4': 7286},
#  740: {'Postal_District': 'EH7',
#   'Demand_P1': 10611,
#   'Demand_P2': 12614,
#   'Demand_P3': 41527,
#   'Demand_P4': 9292},
#  741: {'Postal_District': 'EH8',
#   'Demand_P1': 19415,
#   'Demand_P2': 12583,
#   'Demand_P3': 56675,
#   'Demand_P4': 6526},
#  742: {'Postal_District': 'EH9',
#   'Demand_P1': 37332,
#   'Demand_P2': 21644,
#   'Demand_P3': 247955,
#   'Demand_P4': 29822},
#  690: {'Postal_District': 'EH10',
#   'Demand_P1': 26334,
#   'Demand_P2': 28622,
#   'Demand_P3': 87425,
#   'Demand_P4': 38962},
#  691: {'Postal_District': 'EH11',
#   'Demand_P1': 64866,
#   'Demand_P2': 61979,
#   'Demand_P3': 739281,
#   'Demand_P4': 91807},
#  692: {'Postal_District': 'EH12',
#   'Demand_P1': 34007,
#   'Demand_P2': 38278,
#   'Demand_P3': 243013,
#   'Demand_P4': 56555},
#  693: {'Postal_District': 'EH13',
#   'Demand_P1': 13146,
#   'Demand_P2': 7884,
#   'Demand_P3': 43132,
#   'Demand_P4': 8732},
#  694: {'Postal_District': 'EH14',
#   'Demand_P1': 44109,
#   'Demand_P2': 45099,
#   'Demand_P3': 189903,
#   'Demand_P4': 58497},
#  695: {'Postal_District': 'EH15',
#   'Demand_P1': 19373,
#   'Demand_P2': 15835,
#   'Demand_P3': 139665,
#   'Demand_P4': 12891},
#  696: {'Postal_District': 'EH16',
#   'Demand_P1': 44319,
#   'Demand_P2': 27925,
#   'Demand_P3': 301771,
#   'Demand_P4': 59538},
#  697: {'Postal_District': 'EH17',
#   'Demand_P1': 42473,
#   'Demand_P2': 26318,
#   'Demand_P3': 319308,
#   'Demand_P4': 37730},
#  698: {'Postal_District': 'EH18',
#   'Demand_P1': 1047,
#   'Demand_P2': 1016,
#   'Demand_P3': 5276,
#   'Demand_P4': 726},
#  699: {'Postal_District': 'EH19',
#   'Demand_P1': 19923,
#   'Demand_P2': 15917,
#   'Demand_P3': 156573,
#   'Demand_P4': 27648},
#  701: {'Postal_District': 'EH20',
#   'Demand_P1': 4083,
#   'Demand_P2': 4765,
#   'Demand_P3': 10942,
#   'Demand_P4': 3941},
#  702: {'Postal_District': 'EH21',
#   'Demand_P1': 21029,
#   'Demand_P2': 18959,
#   'Demand_P3': 115096,
#   'Demand_P4': 9332},
#  703: {'Postal_District': 'EH22',
#   'Demand_P1': 33623,
#   'Demand_P2': 27557,
#   'Demand_P3': 234676,
#   'Demand_P4': 20020},
#  704: {'Postal_District': 'EH23',
#   'Demand_P1': 7351,
#   'Demand_P2': 9962,
#   'Demand_P3': 40112,
#   'Demand_P4': 16568},
#  705: {'Postal_District': 'EH24',
#   'Demand_P1': 1966,
#   'Demand_P2': 1386,
#   'Demand_P3': 6097,
#   'Demand_P4': 2128},
#  706: {'Postal_District': 'EH25',
#   'Demand_P1': 2773,
#   'Demand_P2': 2907,
#   'Demand_P3': 20540,
#   'Demand_P4': 5065},
#  707: {'Postal_District': 'EH26',
#   'Demand_P1': 14193,
#   'Demand_P2': 16639,
#   'Demand_P3': 49017,
#   'Demand_P4': 21511},
#  708: {'Postal_District': 'EH27',
#   'Demand_P1': 4159,
#   'Demand_P2': 2132,
#   'Demand_P3': 38693,
#   'Demand_P4': 1796},
#  709: {'Postal_District': 'EH28',
#   'Demand_P1': 2953,
#   'Demand_P2': 1025,
#   'Demand_P3': 17946,
#   'Demand_P4': 532},
#  710: {'Postal_District': 'EH29',
#   'Demand_P1': 4858,
#   'Demand_P2': 1947,
#   'Demand_P3': 18256,
#   'Demand_P4': 1390},
#  712: {'Postal_District': 'EH30',
#   'Demand_P1': 6807,
#   'Demand_P2': 4597,
#   'Demand_P3': 38711,
#   'Demand_P4': 5406},
#  713: {'Postal_District': 'EH31',
#   'Demand_P1': 2602,
#   'Demand_P2': 3512,
#   'Demand_P3': 10494,
#   'Demand_P4': 5142},
#  714: {'Postal_District': 'EH32',
#   'Demand_P1': 18830,
#   'Demand_P2': 21658,
#   'Demand_P3': 145117,
#   'Demand_P4': 42066},
#  715: {'Postal_District': 'EH33',
#   'Demand_P1': 16841,
#   'Demand_P2': 14301,
#   'Demand_P3': 150715,
#   'Demand_P4': 14604},
#  716: {'Postal_District': 'EH34',
#   'Demand_P1': 2172,
#   'Demand_P2': 1839,
#   'Demand_P3': 14993,
#   'Demand_P4': 2070},
#  717: {'Postal_District': 'EH35',
#   'Demand_P1': 3104,
#   'Demand_P2': 1209,
#   'Demand_P3': 14787,
#   'Demand_P4': 1268},
#  718: {'Postal_District': 'EH36',
#   'Demand_P1': 525,
#   'Demand_P2': 249,
#   'Demand_P3': 3065,
#   'Demand_P4': 135},
#  719: {'Postal_District': 'EH37',
#   'Demand_P1': 1057,
#   'Demand_P2': 805,
#   'Demand_P3': 3413,
#   'Demand_P4': 873},
#  720: {'Postal_District': 'EH38',
#   'Demand_P1': 801,
#   'Demand_P2': 327,
#   'Demand_P3': 5790,
#   'Demand_P4': 569},
#  721: {'Postal_District': 'EH39',
#   'Demand_P1': 13084,
#   'Demand_P2': 5155,
#   'Demand_P3': 100812,
#   'Demand_P4': 5009},
#  723: {'Postal_District': 'EH40',
#   'Demand_P1': 2993,
#   'Demand_P2': 1175,
#   'Demand_P3': 18007,
#   'Demand_P4': 1804},
#  724: {'Postal_District': 'EH41',
#   'Demand_P1': 9785,
#   'Demand_P2': 5921,
#   'Demand_P3': 39553,
#   'Demand_P4': 4374},
#  725: {'Postal_District': 'EH42',
#   'Demand_P1': 8082,
#   'Demand_P2': 7109,
#   'Demand_P3': 18006,
#   'Demand_P4': 5514},
#  726: {'Postal_District': 'EH43',
#   'Demand_P1': 1308,
#   'Demand_P2': 801,
#   'Demand_P3': 7082,
#   'Demand_P4': 1007},
#  727: {'Postal_District': 'EH44',
#   'Demand_P1': 2765,
#   'Demand_P2': 1363,
#   'Demand_P3': 12161,
#   'Demand_P4': 883},
#  728: {'Postal_District': 'EH45',
#   'Demand_P1': 11192,
#   'Demand_P2': 3747,
#   'Demand_P3': 59468,
#   'Demand_P4': 2878},
#  729: {'Postal_District': 'EH46',
#   'Demand_P1': 3686,
#   'Demand_P2': 926,
#   'Demand_P3': 9306,
#   'Demand_P4': 967},
#  730: {'Postal_District': 'EH47',
#   'Demand_P1': 23649,
#   'Demand_P2': 25266,
#   'Demand_P3': 94327,
#   'Demand_P4': 43238},
#  731: {'Postal_District': 'EH48',
#   'Demand_P1': 20553,
#   'Demand_P2': 12641,
#   'Demand_P3': 28911,
#   'Demand_P4': 7557},
#  732: {'Postal_District': 'EH49',
#   'Demand_P1': 20984,
#   'Demand_P2': 8147,
#   'Demand_P3': 114301,
#   'Demand_P4': 8272},
#  734: {'Postal_District': 'EH51',
#   'Demand_P1': 12365,
#   'Demand_P2': 10561,
#   'Demand_P3': 39080,
#   'Demand_P4': 7691},
#  735: {'Postal_District': 'EH52',
#   'Demand_P1': 8639,
#   'Demand_P2': 9153,
#   'Demand_P3': 30851,
#   'Demand_P4': 9128},
#  736: {'Postal_District': 'EH53',
#   'Demand_P1': 19246,
#   'Demand_P2': 5612,
#   'Demand_P3': 181971,
#   'Demand_P4': 6994},
#  737: {'Postal_District': 'EH54',
#   'Demand_P1': 53837,
#   'Demand_P2': 35638,
#   'Demand_P3': 261822,
#   'Demand_P4': 29971},
#  738: {'Postal_District': 'EH55',
#   'Demand_P1': 13103,
#   'Demand_P2': 6362,
#   'Demand_P3': 51704,
#   'Demand_P4': 5066},
#  787: {'Postal_District': 'FK1',
#   'Demand_P1': 23404,
#   'Demand_P2': 7221,
#   'Demand_P3': 53664,
#   'Demand_P4': 5249},
#  798: {'Postal_District': 'FK2',
#   'Demand_P1': 25297,
#   'Demand_P2': 9364,
#   'Demand_P3': 84323,
#   'Demand_P4': 6427},
#  801: {'Postal_District': 'FK3',
#   'Demand_P1': 11323,
#   'Demand_P2': 10233,
#   'Demand_P3': 52075,
#   'Demand_P4': 6507},
#  802: {'Postal_District': 'FK4',
#   'Demand_P1': 6147,
#   'Demand_P2': 5714,
#   'Demand_P3': 12947,
#   'Demand_P4': 3399},
#  803: {'Postal_District': 'FK5',
#   'Demand_P1': 30742,
#   'Demand_P2': 13228,
#   'Demand_P3': 280454,
#   'Demand_P4': 25591},
#  804: {'Postal_District': 'FK6',
#   'Demand_P1': 6828,
#   'Demand_P2': 4795,
#   'Demand_P3': 27419,
#   'Demand_P4': 1527},
#  805: {'Postal_District': 'FK7',
#   'Demand_P1': 38719,
#   'Demand_P2': 29590,
#   'Demand_P3': 222853,
#   'Demand_P4': 41274},
#  806: {'Postal_District': 'FK8',
#   'Demand_P1': 14989,
#   'Demand_P2': 11327,
#   'Demand_P3': 83068,
#   'Demand_P4': 11220},
#  807: {'Postal_District': 'FK9',
#   'Demand_P1': 14060,
#   'Demand_P2': 12117,
#   'Demand_P3': 67719,
#   'Demand_P4': 15296},
#  788: {'Postal_District': 'FK10',
#   'Demand_P1': 26198,
#   'Demand_P2': 17016,
#   'Demand_P3': 49724,
#   'Demand_P4': 12785},
#  789: {'Postal_District': 'FK11',
#   'Demand_P1': 2179,
#   'Demand_P2': 838,
#   'Demand_P3': 6078,
#   'Demand_P4': 672},
#  790: {'Postal_District': 'FK12',
#   'Demand_P1': 4259,
#   'Demand_P2': 3928,
#   'Demand_P3': 17547,
#   'Demand_P4': 2118},
#  791: {'Postal_District': 'FK13',
#   'Demand_P1': 4731,
#   'Demand_P2': 2516,
#   'Demand_P3': 37066,
#   'Demand_P4': 2641},
#  792: {'Postal_District': 'FK14',
#   'Demand_P1': 3470,
#   'Demand_P2': 2258,
#   'Demand_P3': 31696,
#   'Demand_P4': 1878},
#  793: {'Postal_District': 'FK15',
#   'Demand_P1': 11141,
#   'Demand_P2': 4272,
#   'Demand_P3': 98651,
#   'Demand_P4': 3399},
#  794: {'Postal_District': 'FK16',
#   'Demand_P1': 2784,
#   'Demand_P2': 2049,
#   'Demand_P3': 16287,
#   'Demand_P4': 3601},
#  795: {'Postal_District': 'FK17',
#   'Demand_P1': 3145,
#   'Demand_P2': 1404,
#   'Demand_P3': 9621,
#   'Demand_P4': 666},
#  796: {'Postal_District': 'FK18',
#   'Demand_P1': 364,
#   'Demand_P2': 193,
#   'Demand_P3': 1397,
#   'Demand_P4': 251},
#  797: {'Postal_District': 'FK19',
#   'Demand_P1': 549,
#   'Demand_P2': 606,
#   'Demand_P3': 2445,
#   'Demand_P4': 917},
#  799: {'Postal_District': 'FK20',
#   'Demand_P1': 383,
#   'Demand_P2': 156,
#   'Demand_P3': 960,
#   'Demand_P4': 102},
#  800: {'Postal_District': 'FK21',
#   'Demand_P1': 609,
#   'Demand_P2': 495,
#   'Demand_P3': 1768,
#   'Demand_P4': 411},
#  817: {'Postal_District': 'G1',
#   'Demand_P1': 11301,
#   'Demand_P2': 7505,
#   'Demand_P3': 41715,
#   'Demand_P4': 9392},
#  823: {'Postal_District': 'G2',
#   'Demand_P1': 2576,
#   'Demand_P2': 3136,
#   'Demand_P3': 9125,
#   'Demand_P4': 2346},
#  828: {'Postal_District': 'G3',
#   'Demand_P1': 12278,
#   'Demand_P2': 9892,
#   'Demand_P3': 35146,
#   'Demand_P4': 5370},
#  833: {'Postal_District': 'G4',
#   'Demand_P1': 24374,
#   'Demand_P2': 6252,
#   'Demand_P3': 193086,
#   'Demand_P4': 9145},
#  841: {'Postal_District': 'G5',
#   'Demand_P1': 7167,
#   'Demand_P2': 12814,
#   'Demand_P3': 55946,
#   'Demand_P4': 14430},
#  818: {'Postal_District': 'G11',
#   'Demand_P1': 20460,
#   'Demand_P2': 10022,
#   'Demand_P3': 138673,
#   'Demand_P4': 9102},
#  819: {'Postal_District': 'G12',
#   'Demand_P1': 11130,
#   'Demand_P2': 19423,
#   'Demand_P3': 35142,
#   'Demand_P4': 19497},
#  820: {'Postal_District': 'G13',
#   'Demand_P1': 39934,
#   'Demand_P2': 16474,
#   'Demand_P3': 261182,
#   'Demand_P4': 18456},
#  821: {'Postal_District': 'G14',
#   'Demand_P1': 38656,
#   'Demand_P2': 15788,
#   'Demand_P3': 331618,
#   'Demand_P4': 13331},
#  822: {'Postal_District': 'G15',
#   'Demand_P1': 21339,
#   'Demand_P2': 8719,
#   'Demand_P3': 120048,
#   'Demand_P4': 12899},
#  824: {'Postal_District': 'G20',
#   'Demand_P1': 54490,
#   'Demand_P2': 27212,
#   'Demand_P3': 548689,
#   'Demand_P4': 28846},
#  825: {'Postal_District': 'G21',
#   'Demand_P1': 41179,
#   'Demand_P2': 17495,
#   'Demand_P3': 177414,
#   'Demand_P4': 27901},
#  826: {'Postal_District': 'G22',
#   'Demand_P1': 8472,
#   'Demand_P2': 9279,
#   'Demand_P3': 44125,
#   'Demand_P4': 9348},
#  827: {'Postal_District': 'G23',
#   'Demand_P1': 7558,
#   'Demand_P2': 8076,
#   'Demand_P3': 31833,
#   'Demand_P4': 11105},
#  829: {'Postal_District': 'G31',
#   'Demand_P1': 19984,
#   'Demand_P2': 14222,
#   'Demand_P3': 75110,
#   'Demand_P4': 18331},
#  830: {'Postal_District': 'G32',
#   'Demand_P1': 35557,
#   'Demand_P2': 39000,
#   'Demand_P3': 154360,
#   'Demand_P4': 37975},
#  831: {'Postal_District': 'G33',
#   'Demand_P1': 21910,
#   'Demand_P2': 16174,
#   'Demand_P3': 45056,
#   'Demand_P4': 8033},
#  832: {'Postal_District': 'G34',
#   'Demand_P1': 6227,
#   'Demand_P2': 4581,
#   'Demand_P3': 54691,
#   'Demand_P4': 8091},
#  834: {'Postal_District': 'G40',
#   'Demand_P1': 7154,
#   'Demand_P2': 3672,
#   'Demand_P3': 15244,
#   'Demand_P4': 1925},
#  835: {'Postal_District': 'G41',
#   'Demand_P1': 39012,
#   'Demand_P2': 38244,
#   'Demand_P3': 226836,
#   'Demand_P4': 73643},
#  836: {'Postal_District': 'G42',
#   'Demand_P1': 36916,
#   'Demand_P2': 30378,
#   'Demand_P3': 174281,
#   'Demand_P4': 35287},
#  837: {'Postal_District': 'G43',
#   'Demand_P1': 17057,
#   'Demand_P2': 17204,
#   'Demand_P3': 137801,
#   'Demand_P4': 20826},
#  838: {'Postal_District': 'G44',
#   'Demand_P1': 49181,
#   'Demand_P2': 23622,
#   'Demand_P3': 381746,
#   'Demand_P4': 32014},
#  839: {'Postal_District': 'G45',
#   'Demand_P1': 28714,
#   'Demand_P2': 10015,
#   'Demand_P3': 195337,
#   'Demand_P4': 15402},
#  840: {'Postal_District': 'G46',
#   'Demand_P1': 16957,
#   'Demand_P2': 15053,
#   'Demand_P3': 78937,
#   'Demand_P4': 6762},
#  842: {'Postal_District': 'G51',
#   'Demand_P1': 31739,
#   'Demand_P2': 30061,
#   'Demand_P3': 266922,
#   'Demand_P4': 36669},
#  843: {'Postal_District': 'G52',
#   'Demand_P1': 15258,
#   'Demand_P2': 22219,
#   'Demand_P3': 54997,
#   'Demand_P4': 21707},
#  844: {'Postal_District': 'G53',
#   'Demand_P1': 16755,
#   'Demand_P2': 9987,
#   'Demand_P3': 73581,
#   'Demand_P4': 9711},
#  845: {'Postal_District': 'G60',
#   'Demand_P1': 6544,
#   'Demand_P2': 4457,
#   'Demand_P3': 23720,
#   'Demand_P4': 2537},
#  846: {'Postal_District': 'G61',
#   'Demand_P1': 16162,
#   'Demand_P2': 10215,
#   'Demand_P3': 55738,
#   'Demand_P4': 5326},
#  847: {'Postal_District': 'G62',
#   'Demand_P1': 10071,
#   'Demand_P2': 3289,
#   'Demand_P3': 40108,
#   'Demand_P4': 1229},
#  848: {'Postal_District': 'G63',
#   'Demand_P1': 14874,
#   'Demand_P2': 3549,
#   'Demand_P3': 48750,
#   'Demand_P4': 4134},
#  849: {'Postal_District': 'G64',
#   'Demand_P1': 23554,
#   'Demand_P2': 15651,
#   'Demand_P3': 43126,
#   'Demand_P4': 12920},
#  850: {'Postal_District': 'G65',
#   'Demand_P1': 23286,
#   'Demand_P2': 13431,
#   'Demand_P3': 160543,
#   'Demand_P4': 12429},
#  851: {'Postal_District': 'G66',
#   'Demand_P1': 43254,
#   'Demand_P2': 23874,
#   'Demand_P3': 103637,
#   'Demand_P4': 25822},
#  852: {'Postal_District': 'G67',
#   'Demand_P1': 13019,
#   'Demand_P2': 15269,
#   'Demand_P3': 25280,
#   'Demand_P4': 7863},
#  853: {'Postal_District': 'G68',
#   'Demand_P1': 21237,
#   'Demand_P2': 18113,
#   'Demand_P3': 166172,
#   'Demand_P4': 16706},
#  854: {'Postal_District': 'G69',
#   'Demand_P1': 28746,
#   'Demand_P2': 18302,
#   'Demand_P3': 119802,
#   'Demand_P4': 6102},
#  855: {'Postal_District': 'G71',
#   'Demand_P1': 43550,
#   'Demand_P2': 13726,
#   'Demand_P3': 343524,
#   'Demand_P4': 24478},
#  856: {'Postal_District': 'G72',
#   'Demand_P1': 43380,
#   'Demand_P2': 36158,
#   'Demand_P3': 156510,
#   'Demand_P4': 20000},
#  857: {'Postal_District': 'G73',
#   'Demand_P1': 26228,
#   'Demand_P2': 22014,
#   'Demand_P3': 173091,
#   'Demand_P4': 38078},
#  858: {'Postal_District': 'G74',
#   'Demand_P1': 48288,
#   'Demand_P2': 23682,
#   'Demand_P3': 195912,
#   'Demand_P4': 25437},
#  859: {'Postal_District': 'G75',
#   'Demand_P1': 34090,
#   'Demand_P2': 11830,
#   'Demand_P3': 76852,
#   'Demand_P4': 12653},
#  860: {'Postal_District': 'G76',
#   'Demand_P1': 30126,
#   'Demand_P2': 18628,
#   'Demand_P3': 220928,
#   'Demand_P4': 29508},
#  861: {'Postal_District': 'G77',
#   'Demand_P1': 26440,
#   'Demand_P2': 20683,
#   'Demand_P3': 284175,
#   'Demand_P4': 24282},
#  862: {'Postal_District': 'G78',
#   'Demand_P1': 34963,
#   'Demand_P2': 15381,
#   'Demand_P3': 212215,
#   'Demand_P4': 15797},
#  863: {'Postal_District': 'G81',
#   'Demand_P1': 62353,
#   'Demand_P2': 22106,
#   'Demand_P3': 400838,
#   'Demand_P4': 40935},
#  864: {'Postal_District': 'G82',
#   'Demand_P1': 19254,
#   'Demand_P2': 18360,
#   'Demand_P3': 133784,
#   'Demand_P4': 10811},
#  865: {'Postal_District': 'G83',
#   'Demand_P1': 36038,
#   'Demand_P2': 28713,
#   'Demand_P3': 316651,
#   'Demand_P4': 57557},
#  866: {'Postal_District': 'G84',
#   'Demand_P1': 17407,
#   'Demand_P2': 10036,
#   'Demand_P3': 184117,
#   'Demand_P4': 8051},
#  989: {'Postal_District': 'HS1',
#   'Demand_P1': 2629,
#   'Demand_P2': 2120,
#   'Demand_P3': 19103,
#   'Demand_P4': 1942},
#  990: {'Postal_District': 'HS2',
#   'Demand_P1': 4973,
#   'Demand_P2': 4640,
#   'Demand_P3': 13598,
#   'Demand_P4': 3350},
#  991: {'Postal_District': 'HS3',
#   'Demand_P1': 2028,
#   'Demand_P2': 1628,
#   'Demand_P3': 20141,
#   'Demand_P4': 1145},
#  992: {'Postal_District': 'HS4',
#   'Demand_P1': 312,
#   'Demand_P2': 244,
#   'Demand_P3': 2319,
#   'Demand_P4': 295},
#  993: {'Postal_District': 'HS5',
#   'Demand_P1': 286,
#   'Demand_P2': 161,
#   'Demand_P3': 1423,
#   'Demand_P4': 204},
#  994: {'Postal_District': 'HS6',
#   'Demand_P1': 1157,
#   'Demand_P2': 1012,
#   'Demand_P3': 5383,
#   'Demand_P4': 2039},
#  995: {'Postal_District': 'HS7',
#   'Demand_P1': 2002,
#   'Demand_P2': 543,
#   'Demand_P3': 8958,
#   'Demand_P4': 483},
#  996: {'Postal_District': 'HS8',
#   'Demand_P1': 2848,
#   'Demand_P2': 881,
#   'Demand_P3': 13620,
#   'Demand_P4': 1044},
#  997: {'Postal_District': 'HS9',
#   'Demand_P1': 1018,
#   'Demand_P2': 483,
#   'Demand_P3': 4153,
#   'Demand_P4': 268},
#  1069: {'Postal_District': 'IV1',
#   'Demand_P1': 1691,
#   'Demand_P2': 1300,
#   'Demand_P3': 9501,
#   'Demand_P4': 2212},
#  1080: {'Postal_District': 'IV2',
#   'Demand_P1': 34763,
#   'Demand_P2': 34753,
#   'Demand_P3': 154481,
#   'Demand_P4': 31331},
#  1090: {'Postal_District': 'IV3',
#   'Demand_P1': 14432,
#   'Demand_P2': 24617,
#   'Demand_P3': 132184,
#   'Demand_P4': 33499},
#  1095: {'Postal_District': 'IV4',
#   'Demand_P1': 3762,
#   'Demand_P2': 1720,
#   'Demand_P3': 10484,
#   'Demand_P4': 1216},
#  1106: {'Postal_District': 'IV5',
#   'Demand_P1': 1268,
#   'Demand_P2': 833,
#   'Demand_P3': 4736,
#   'Demand_P4': 799},
#  1113: {'Postal_District': 'IV6',
#   'Demand_P1': 2810,
#   'Demand_P2': 1412,
#   'Demand_P3': 10806,
#   'Demand_P4': 711},
#  1115: {'Postal_District': 'IV7',
#   'Demand_P1': 12921,
#   'Demand_P2': 4509,
#   'Demand_P3': 145434,
#   'Demand_P4': 6796},
#  1116: {'Postal_District': 'IV8',
#   'Demand_P1': 1163,
#   'Demand_P2': 514,
#   'Demand_P3': 8240,
#   'Demand_P4': 781},
#  1117: {'Postal_District': 'IV9',
#   'Demand_P1': 1025,
#   'Demand_P2': 638,
#   'Demand_P3': 2672,
#   'Demand_P4': 238},
#  1070: {'Postal_District': 'IV10',
#   'Demand_P1': 920,
#   'Demand_P2': 1022,
#   'Demand_P3': 3983,
#   'Demand_P4': 770},
#  1071: {'Postal_District': 'IV11',
#   'Demand_P1': 1023,
#   'Demand_P2': 387,
#   'Demand_P3': 3841,
#   'Demand_P4': 391},
#  1072: {'Postal_District': 'IV12',
#   'Demand_P1': 6146,
#   'Demand_P2': 5121,
#   'Demand_P3': 13688,
#   'Demand_P4': 3026},
#  1073: {'Postal_District': 'IV13',
#   'Demand_P1': 380,
#   'Demand_P2': 486,
#   'Demand_P3': 1976,
#   'Demand_P4': 277},
#  1074: {'Postal_District': 'IV14',
#   'Demand_P1': 1317,
#   'Demand_P2': 746,
#   'Demand_P3': 7078,
#   'Demand_P4': 758},
#  1075: {'Postal_District': 'IV15',
#   'Demand_P1': 10073,
#   'Demand_P2': 6075,
#   'Demand_P3': 96537,
#   'Demand_P4': 6984},
#  1076: {'Postal_District': 'IV16',
#   'Demand_P1': 3080,
#   'Demand_P2': 2119,
#   'Demand_P3': 21528,
#   'Demand_P4': 4588},
#  1077: {'Postal_District': 'IV17',
#   'Demand_P1': 3785,
#   'Demand_P2': 5124,
#   'Demand_P3': 11126,
#   'Demand_P4': 2710},
#  1078: {'Postal_District': 'IV18',
#   'Demand_P1': 13182,
#   'Demand_P2': 9025,
#   'Demand_P3': 76801,
#   'Demand_P4': 14499},
#  1079: {'Postal_District': 'IV19',
#   'Demand_P1': 1743,
#   'Demand_P2': 1090,
#   'Demand_P3': 3624,
#   'Demand_P4': 675},
#  1081: {'Postal_District': 'IV20',
#   'Demand_P1': 2427,
#   'Demand_P2': 2920,
#   'Demand_P3': 11994,
#   'Demand_P4': 4702},
#  1082: {'Postal_District': 'IV21',
#   'Demand_P1': 1333,
#   'Demand_P2': 487,
#   'Demand_P3': 7137,
#   'Demand_P4': 480},
#  1083: {'Postal_District': 'IV22',
#   'Demand_P1': 1500,
#   'Demand_P2': 530,
#   'Demand_P3': 8241,
#   'Demand_P4': 471},
#  1084: {'Postal_District': 'IV23',
#   'Demand_P1': 1650,
#   'Demand_P2': 493,
#   'Demand_P3': 9353,
#   'Demand_P4': 898},
#  1085: {'Postal_District': 'IV24',
#   'Demand_P1': 937,
#   'Demand_P2': 495,
#   'Demand_P3': 2677,
#   'Demand_P4': 340},
#  1086: {'Postal_District': 'IV25',
#   'Demand_P1': 2487,
#   'Demand_P2': 906,
#   'Demand_P3': 13262,
#   'Demand_P4': 1011},
#  1087: {'Postal_District': 'IV26',
#   'Demand_P1': 3519,
#   'Demand_P2': 2324,
#   'Demand_P3': 28286,
#   'Demand_P4': 4050},
#  1088: {'Postal_District': 'IV27',
#   'Demand_P1': 6000,
#   'Demand_P2': 4857,
#   'Demand_P3': 55504,
#   'Demand_P4': 3779},
#  1089: {'Postal_District': 'IV28',
#   'Demand_P1': 282,
#   'Demand_P2': 516,
#   'Demand_P3': 1542,
#   'Demand_P4': 392},
#  1091: {'Postal_District': 'IV30',
#   'Demand_P1': 43443,
#   'Demand_P2': 19782,
#   'Demand_P3': 347064,
#   'Demand_P4': 23367},
#  1092: {'Postal_District': 'IV31',
#   'Demand_P1': 12874,
#   'Demand_P2': 9972,
#   'Demand_P3': 67671,
#   'Demand_P4': 9952},
#  1093: {'Postal_District': 'IV32',
#   'Demand_P1': 2153,
#   'Demand_P2': 2790,
#   'Demand_P3': 8729,
#   'Demand_P4': 2316},
#  1094: {'Postal_District': 'IV36',
#   'Demand_P1': 15139,
#   'Demand_P2': 10614,
#   'Demand_P3': 94480,
#   'Demand_P4': 5033},
#  1096: {'Postal_District': 'IV40',
#   'Demand_P1': 2946,
#   'Demand_P2': 1674,
#   'Demand_P3': 18288,
#   'Demand_P4': 3669},
#  1097: {'Postal_District': 'IV41',
#   'Demand_P1': 251,
#   'Demand_P2': 80,
#   'Demand_P3': 469,
#   'Demand_P4': 67},
#  1098: {'Postal_District': 'IV42',
#   'Demand_P1': 596,
#   'Demand_P2': 243,
#   'Demand_P3': 3051,
#   'Demand_P4': 385},
#  1099: {'Postal_District': 'IV43',
#   'Demand_P1': 110,
#   'Demand_P2': 76,
#   'Demand_P3': 411,
#   'Demand_P4': 54},
#  1100: {'Postal_District': 'IV44',
#   'Demand_P1': 201,
#   'Demand_P2': 146,
#   'Demand_P3': 1192,
#   'Demand_P4': 152},
#  1101: {'Postal_District': 'IV45',
#   'Demand_P1': 522,
#   'Demand_P2': 130,
#   'Demand_P3': 2946,
#   'Demand_P4': 257},
#  1102: {'Postal_District': 'IV46',
#   'Demand_P1': 77,
#   'Demand_P2': 56,
#   'Demand_P3': 578,
#   'Demand_P4': 73},
#  1103: {'Postal_District': 'IV47',
#   'Demand_P1': 674,
#   'Demand_P2': 484,
#   'Demand_P3': 3124,
#   'Demand_P4': 626},
#  1104: {'Postal_District': 'IV48',
#   'Demand_P1': 66,
#   'Demand_P2': 43,
#   'Demand_P3': 370,
#   'Demand_P4': 20},
#  1105: {'Postal_District': 'IV49',
#   'Demand_P1': 1296,
#   'Demand_P2': 1073,
#   'Demand_P3': 8124,
#   'Demand_P4': 1760},
#  1107: {'Postal_District': 'IV51',
#   'Demand_P1': 5631,
#   'Demand_P2': 4297,
#   'Demand_P3': 25947,
#   'Demand_P4': 4462},
#  1108: {'Postal_District': 'IV52',
#   'Demand_P1': 207,
#   'Demand_P2': 145,
#   'Demand_P3': 720,
#   'Demand_P4': 164},
#  1109: {'Postal_District': 'IV53',
#   'Demand_P1': 65,
#   'Demand_P2': 47,
#   'Demand_P3': 190,
#   'Demand_P4': 19},
#  1110: {'Postal_District': 'IV54',
#   'Demand_P1': 2293,
#   'Demand_P2': 1866,
#   'Demand_P3': 16903,
#   'Demand_P4': 2043},
#  1111: {'Postal_District': 'IV55',
#   'Demand_P1': 992,
#   'Demand_P2': 952,
#   'Demand_P3': 5019,
#   'Demand_P4': 418},
#  1112: {'Postal_District': 'IV56',
#   'Demand_P1': 268,
#   'Demand_P2': 94,
#   'Demand_P3': 555,
#   'Demand_P4': 64},
#  1114: {'Postal_District': 'IV63',
#   'Demand_P1': 1608,
#   'Demand_P2': 1726,
#   'Demand_P3': 8479,
#   'Demand_P4': 872},
#  1118: {'Postal_District': 'KA1',
#   'Demand_P1': 39742,
#   'Demand_P2': 29930,
#   'Demand_P3': 326453,
#   'Demand_P4': 28898},
#  1129: {'Postal_District': 'KA2',
#   'Demand_P1': 3568,
#   'Demand_P2': 2715,
#   'Demand_P3': 14723,
#   'Demand_P4': 2316},
#  1140: {'Postal_District': 'KA3',
#   'Demand_P1': 32124,
#   'Demand_P2': 26919,
#   'Demand_P3': 137246,
#   'Demand_P4': 36834},
#  1142: {'Postal_District': 'KA4',
#   'Demand_P1': 6332,
#   'Demand_P2': 4859,
#   'Demand_P3': 46019,
#   'Demand_P4': 3203},
#  1143: {'Postal_District': 'KA5',
#   'Demand_P1': 8235,
#   'Demand_P2': 8713,
#   'Demand_P3': 54952,
#   'Demand_P4': 10247},
#  1144: {'Postal_District': 'KA6',
#   'Demand_P1': 19416,
#   'Demand_P2': 6731,
#   'Demand_P3': 85533,
#   'Demand_P4': 10740},
#  1145: {'Postal_District': 'KA7',
#   'Demand_P1': 21081,
#   'Demand_P2': 11618,
#   'Demand_P3': 79681,
#   'Demand_P4': 13308},
#  1146: {'Postal_District': 'KA8',
#   'Demand_P1': 24251,
#   'Demand_P2': 18961,
#   'Demand_P3': 193327,
#   'Demand_P4': 20091},
#  1147: {'Postal_District': 'KA9',
#   'Demand_P1': 15218,
#   'Demand_P2': 9137,
#   'Demand_P3': 82358,
#   'Demand_P4': 8229},
#  1119: {'Postal_District': 'KA10',
#   'Demand_P1': 6788,
#   'Demand_P2': 4565,
#   'Demand_P3': 14508,
#   'Demand_P4': 3438},
#  1120: {'Postal_District': 'KA11',
#   'Demand_P1': 11282,
#   'Demand_P2': 13613,
#   'Demand_P3': 44540,
#   'Demand_P4': 18227},
#  1121: {'Postal_District': 'KA12',
#   'Demand_P1': 22571,
#   'Demand_P2': 12683,
#   'Demand_P3': 127467,
#   'Demand_P4': 20377},
#  1122: {'Postal_District': 'KA13',
#   'Demand_P1': 10301,
#   'Demand_P2': 10208,
#   'Demand_P3': 50844,
#   'Demand_P4': 7770},
#  1123: {'Postal_District': 'KA14',
#   'Demand_P1': 530,
#   'Demand_P2': 584,
#   'Demand_P3': 5514,
#   'Demand_P4': 1033},
#  1124: {'Postal_District': 'KA15',
#   'Demand_P1': 5151,
#   'Demand_P2': 2504,
#   'Demand_P3': 17764,
#   'Demand_P4': 969},
#  1125: {'Postal_District': 'KA16',
#   'Demand_P1': 2852,
#   'Demand_P2': 1987,
#   'Demand_P3': 15044,
#   'Demand_P4': 1279},
#  1126: {'Postal_District': 'KA17',
#   'Demand_P1': 3179,
#   'Demand_P2': 1952,
#   'Demand_P3': 13453,
#   'Demand_P4': 1668},
#  1127: {'Postal_District': 'KA18',
#   'Demand_P1': 10777,
#   'Demand_P2': 4108,
#   'Demand_P3': 19284,
#   'Demand_P4': 1586},
#  1128: {'Postal_District': 'KA19',
#   'Demand_P1': 10793,
#   'Demand_P2': 4253,
#   'Demand_P3': 60293,
#   'Demand_P4': 3704},
#  1130: {'Postal_District': 'KA20',
#   'Demand_P1': 11050,
#   'Demand_P2': 6794,
#   'Demand_P3': 43919,
#   'Demand_P4': 2898},
#  1131: {'Postal_District': 'KA21',
#   'Demand_P1': 5136,
#   'Demand_P2': 9532,
#   'Demand_P3': 12485,
#   'Demand_P4': 10738},
#  1132: {'Postal_District': 'KA22',
#   'Demand_P1': 7852,
#   'Demand_P2': 5343,
#   'Demand_P3': 34972,
#   'Demand_P4': 3815},
#  1133: {'Postal_District': 'KA23',
#   'Demand_P1': 4294,
#   'Demand_P2': 1444,
#   'Demand_P3': 10794,
#   'Demand_P4': 1106},
#  1134: {'Postal_District': 'KA24',
#   'Demand_P1': 4379,
#   'Demand_P2': 3166,
#   'Demand_P3': 12668,
#   'Demand_P4': 2434},
#  1135: {'Postal_District': 'KA25',
#   'Demand_P1': 12547,
#   'Demand_P2': 9288,
#   'Demand_P3': 134942,
#   'Demand_P4': 16104},
#  1136: {'Postal_District': 'KA26',
#   'Demand_P1': 16022,
#   'Demand_P2': 9278,
#   'Demand_P3': 57077,
#   'Demand_P4': 8348},
#  1137: {'Postal_District': 'KA27',
#   'Demand_P1': 5557,
#   'Demand_P2': 3836,
#   'Demand_P3': 18997,
#   'Demand_P4': 5665},
#  1138: {'Postal_District': 'KA28',
#   'Demand_P1': 1315,
#   'Demand_P2': 887,
#   'Demand_P3': 11657,
#   'Demand_P4': 1256},
#  1139: {'Postal_District': 'KA29',
#   'Demand_P1': 1308,
#   'Demand_P2': 1053,
#   'Demand_P3': 6108,
#   'Demand_P4': 1304},
#  1141: {'Postal_District': 'KA30',
#   'Demand_P1': 8509,
#   'Demand_P2': 6771,
#   'Demand_P3': 25812,
#   'Demand_P4': 6667},
#  1172: {'Postal_District': 'KW1',
#   'Demand_P1': 9570,
#   'Demand_P2': 4189,
#   'Demand_P3': 22150,
#   'Demand_P4': 3861},
#  1181: {'Postal_District': 'KW2',
#   'Demand_P1': 32,
#   'Demand_P2': 46,
#   'Demand_P3': 105,
#   'Demand_P4': 18},
#  1182: {'Postal_District': 'KW3',
#   'Demand_P1': 1643,
#   'Demand_P2': 621,
#   'Demand_P3': 15410,
#   'Demand_P4': 1231},
#  1183: {'Postal_District': 'KW5',
#   'Demand_P1': 206,
#   'Demand_P2': 192,
#   'Demand_P3': 1627,
#   'Demand_P4': 224},
#  1184: {'Postal_District': 'KW6',
#   'Demand_P1': 349,
#   'Demand_P2': 282,
#   'Demand_P3': 1203,
#   'Demand_P4': 112},
#  1185: {'Postal_District': 'KW7',
#   'Demand_P1': 115,
#   'Demand_P2': 100,
#   'Demand_P3': 587,
#   'Demand_P4': 104},
#  1186: {'Postal_District': 'KW8',
#   'Demand_P1': 871,
#   'Demand_P2': 735,
#   'Demand_P3': 2087,
#   'Demand_P4': 596},
#  1187: {'Postal_District': 'KW9',
#   'Demand_P1': 1964,
#   'Demand_P2': 674,
#   'Demand_P3': 12851,
#   'Demand_P4': 421},
#  1173: {'Postal_District': 'KW10',
#   'Demand_P1': 2583,
#   'Demand_P2': 1559,
#   'Demand_P3': 9337,
#   'Demand_P4': 1248},
#  1174: {'Postal_District': 'KW11',
#   'Demand_P1': 50,
#   'Demand_P2': 73,
#   'Demand_P3': 99,
#   'Demand_P4': 36},
#  1175: {'Postal_District': 'KW12',
#   'Demand_P1': 1284,
#   'Demand_P2': 1087,
#   'Demand_P3': 4717,
#   'Demand_P4': 1804},
#  1176: {'Postal_District': 'KW13',
#   'Demand_P1': 61,
#   'Demand_P2': 103,
#   'Demand_P3': 459,
#   'Demand_P4': 124},
#  1177: {'Postal_District': 'KW14',
#   'Demand_P1': 15741,
#   'Demand_P2': 7007,
#   'Demand_P3': 105232,
#   'Demand_P4': 8420},
#  1178: {'Postal_District': 'KW15',
#   'Demand_P1': 14380,
#   'Demand_P2': 9481,
#   'Demand_P3': 138393,
#   'Demand_P4': 9601},
#  1179: {'Postal_District': 'KW16',
#   'Demand_P1': 2512,
#   'Demand_P2': 2508,
#   'Demand_P3': 9512,
#   'Demand_P4': 1659},
#  1180: {'Postal_District': 'KW17',
#   'Demand_P1': 7369,
#   'Demand_P2': 6231,
#   'Demand_P3': 23343,
#   'Demand_P4': 10545},
#  1188: {'Postal_District': 'KY1',
#   'Demand_P1': 17632,
#   'Demand_P2': 11163,
#   'Demand_P3': 56462,
#   'Demand_P4': 8654},
#  1196: {'Postal_District': 'KY2',
#   'Demand_P1': 27006,
#   'Demand_P2': 19211,
#   'Demand_P3': 117731,
#   'Demand_P4': 19445},
#  1197: {'Postal_District': 'KY3',
#   'Demand_P1': 7507,
#   'Demand_P2': 11488,
#   'Demand_P3': 36475,
#   'Demand_P4': 17549},
#  1198: {'Postal_District': 'KY4',
#   'Demand_P1': 29392,
#   'Demand_P2': 14061,
#   'Demand_P3': 97685,
#   'Demand_P4': 7988},
#  1199: {'Postal_District': 'KY5',
#   'Demand_P1': 10655,
#   'Demand_P2': 6626,
#   'Demand_P3': 43013,
#   'Demand_P4': 4624},
#  1200: {'Postal_District': 'KY6',
#   'Demand_P1': 15045,
#   'Demand_P2': 16177,
#   'Demand_P3': 40414,
#   'Demand_P4': 12236},
#  1201: {'Postal_District': 'KY7',
#   'Demand_P1': 20900,
#   'Demand_P2': 19083,
#   'Demand_P3': 71297,
#   'Demand_P4': 16075},
#  1202: {'Postal_District': 'KY8',
#   'Demand_P1': 20825,
#   'Demand_P2': 27470,
#   'Demand_P3': 168748,
#   'Demand_P4': 18160},
#  1203: {'Postal_District': 'KY9',
#   'Demand_P1': 736,
#   'Demand_P2': 1152,
#   'Demand_P3': 3446,
#   'Demand_P4': 801},
#  1189: {'Postal_District': 'KY10',
#   'Demand_P1': 7752,
#   'Demand_P2': 6833,
#   'Demand_P3': 52115,
#   'Demand_P4': 9723},
#  1190: {'Postal_District': 'KY11',
#   'Demand_P1': 25013,
#   'Demand_P2': 19387,
#   'Demand_P3': 91959,
#   'Demand_P4': 17329},
#  1191: {'Postal_District': 'KY12',
#   'Demand_P1': 42723,
#   'Demand_P2': 18371,
#   'Demand_P3': 108958,
#   'Demand_P4': 14892},
#  1192: {'Postal_District': 'KY13',
#   'Demand_P1': 3193,
#   'Demand_P2': 1971,
#   'Demand_P3': 5810,
#   'Demand_P4': 1251},
#  1193: {'Postal_District': 'KY14',
#   'Demand_P1': 6828,
#   'Demand_P2': 2520,
#   'Demand_P3': 18911,
#   'Demand_P4': 1405},
#  1194: {'Postal_District': 'KY15',
#   'Demand_P1': 14217,
#   'Demand_P2': 13957,
#   'Demand_P3': 91227,
#   'Demand_P4': 8780},
#  1195: {'Postal_District': 'KY16',
#   'Demand_P1': 37921,
#   'Demand_P2': 10034,
#   'Demand_P3': 133969,
#   'Demand_P4': 11259},
#  1502: {'Postal_District': 'ML1',
#   'Demand_P1': 57909,
#   'Demand_P2': 50594,
#   'Demand_P3': 501279,
#   'Demand_P4': 59251},
#  1506: {'Postal_District': 'ML2',
#   'Demand_P1': 41399,
#   'Demand_P2': 21128,
#   'Demand_P3': 264886,
#   'Demand_P4': 18760},
#  1507: {'Postal_District': 'ML3',
#   'Demand_P1': 34477,
#   'Demand_P2': 17067,
#   'Demand_P3': 105688,
#   'Demand_P4': 17035},
#  1508: {'Postal_District': 'ML4',
#   'Demand_P1': 36033,
#   'Demand_P2': 14990,
#   'Demand_P3': 290465,
#   'Demand_P4': 22870},
#  1509: {'Postal_District': 'ML5',
#   'Demand_P1': 48577,
#   'Demand_P2': 38266,
#   'Demand_P3': 381820,
#   'Demand_P4': 43393},
#  1510: {'Postal_District': 'ML6',
#   'Demand_P1': 69964,
#   'Demand_P2': 45981,
#   'Demand_P3': 601282,
#   'Demand_P4': 52273},
#  1511: {'Postal_District': 'ML7',
#   'Demand_P1': 26311,
#   'Demand_P2': 16723,
#   'Demand_P3': 115984,
#   'Demand_P4': 16928},
#  1512: {'Postal_District': 'ML8',
#   'Demand_P1': 30625,
#   'Demand_P2': 12312,
#   'Demand_P3': 199643,
#   'Demand_P4': 8983},
#  1513: {'Postal_District': 'ML9',
#   'Demand_P1': 46617,
#   'Demand_P2': 31233,
#   'Demand_P3': 311417,
#   'Demand_P4': 35633},
#  1503: {'Postal_District': 'ML10',
#   'Demand_P1': 8364,
#   'Demand_P2': 5661,
#   'Demand_P3': 38145,
#   'Demand_P4': 6986},
#  1504: {'Postal_District': 'ML11',
#   'Demand_P1': 26757,
#   'Demand_P2': 12914,
#   'Demand_P3': 69102,
#   'Demand_P4': 9840},
#  1505: {'Postal_District': 'ML12',
#   'Demand_P1': 8153,
#   'Demand_P2': 5763,
#   'Demand_P3': 19279,
#   'Demand_P4': 4894},
#  1750: {'Postal_District': 'PA1',
#   'Demand_P1': 14082,
#   'Demand_P2': 14692,
#   'Demand_P3': 73108,
#   'Demand_P4': 15758},
#  1761: {'Postal_District': 'PA2',
#   'Demand_P1': 16255,
#   'Demand_P2': 21340,
#   'Demand_P3': 60966,
#   'Demand_P4': 20317},
#  1772: {'Postal_District': 'PA3',
#   'Demand_P1': 33189,
#   'Demand_P2': 16421,
#   'Demand_P3': 159746,
#   'Demand_P4': 28586},
#  1782: {'Postal_District': 'PA4',
#   'Demand_P1': 21544,
#   'Demand_P2': 10993,
#   'Demand_P3': 63599,
#   'Demand_P4': 17384},
#  1792: {'Postal_District': 'PA5',
#   'Demand_P1': 23776,
#   'Demand_P2': 15430,
#   'Demand_P3': 115685,
#   'Demand_P4': 26288},
#  1793: {'Postal_District': 'PA6',
#   'Demand_P1': 8112,
#   'Demand_P2': 4999,
#   'Demand_P3': 66600,
#   'Demand_P4': 4139},
#  1804: {'Postal_District': 'PA7',
#   'Demand_P1': 9010,
#   'Demand_P2': 2125,
#   'Demand_P3': 66932,
#   'Demand_P4': 4008},
#  1814: {'Postal_District': 'PA8',
#   'Demand_P1': 14093,
#   'Demand_P2': 9186,
#   'Demand_P3': 40985,
#   'Demand_P4': 8148},
#  1816: {'Postal_District': 'PA9',
#   'Demand_P1': 2608,
#   'Demand_P2': 1173,
#   'Demand_P3': 19893,
#   'Demand_P4': 882},
#  1751: {'Postal_District': 'PA10',
#   'Demand_P1': 3350,
#   'Demand_P2': 2058,
#   'Demand_P3': 16819,
#   'Demand_P4': 1778},
#  1752: {'Postal_District': 'PA11',
#   'Demand_P1': 4414,
#   'Demand_P2': 3456,
#   'Demand_P3': 20807,
#   'Demand_P4': 1734},
#  1753: {'Postal_District': 'PA12',
#   'Demand_P1': 3032,
#   'Demand_P2': 1273,
#   'Demand_P3': 7717,
#   'Demand_P4': 790},
#  1754: {'Postal_District': 'PA13',
#   'Demand_P1': 8585,
#   'Demand_P2': 4357,
#   'Demand_P3': 34896,
#   'Demand_P4': 3609},
#  1755: {'Postal_District': 'PA14',
#   'Demand_P1': 31804,
#   'Demand_P2': 20586,
#   'Demand_P3': 272080,
#   'Demand_P4': 22335},
#  1756: {'Postal_District': 'PA15',
#   'Demand_P1': 11674,
#   'Demand_P2': 12842,
#   'Demand_P3': 51079,
#   'Demand_P4': 18328},
#  1757: {'Postal_District': 'PA16',
#   'Demand_P1': 20890,
#   'Demand_P2': 15982,
#   'Demand_P3': 74875,
#   'Demand_P4': 5037},
#  1758: {'Postal_District': 'PA17',
#   'Demand_P1': 1632,
#   'Demand_P2': 1216,
#   'Demand_P3': 9613,
#   'Demand_P4': 971},
#  1759: {'Postal_District': 'PA18',
#   'Demand_P1': 2785,
#   'Demand_P2': 990,
#   'Demand_P3': 19830,
#   'Demand_P4': 1219},
#  1760: {'Postal_District': 'PA19',
#   'Demand_P1': 20558,
#   'Demand_P2': 17053,
#   'Demand_P3': 91973,
#   'Demand_P4': 31915},
#  1762: {'Postal_District': 'PA20',
#   'Demand_P1': 4656,
#   'Demand_P2': 3200,
#   'Demand_P3': 14082,
#   'Demand_P4': 3533},
#  1763: {'Postal_District': 'PA21',
#   'Demand_P1': 594,
#   'Demand_P2': 411,
#   'Demand_P3': 3972,
#   'Demand_P4': 336},
#  1764: {'Postal_District': 'PA22',
#   'Demand_P1': 309,
#   'Demand_P2': 253,
#   'Demand_P3': 865,
#   'Demand_P4': 237},
#  1765: {'Postal_District': 'PA23',
#   'Demand_P1': 9442,
#   'Demand_P2': 9444,
#   'Demand_P3': 26319,
#   'Demand_P4': 5239},
#  1766: {'Postal_District': 'PA24',
#   'Demand_P1': 252,
#   'Demand_P2': 221,
#   'Demand_P3': 645,
#   'Demand_P4': 144},
#  1767: {'Postal_District': 'PA25',
#   'Demand_P1': 80,
#   'Demand_P2': 45,
#   'Demand_P3': 273,
#   'Demand_P4': 56},
#  1768: {'Postal_District': 'PA26',
#   'Demand_P1': 80,
#   'Demand_P2': 30,
#   'Demand_P3': 150,
#   'Demand_P4': 22},
#  1769: {'Postal_District': 'PA27',
#   'Demand_P1': 198,
#   'Demand_P2': 244,
#   'Demand_P3': 483,
#   'Demand_P4': 118},
#  1770: {'Postal_District': 'PA28',
#   'Demand_P1': 5743,
#   'Demand_P2': 5768,
#   'Demand_P3': 31624,
#   'Demand_P4': 3189},
#  1771: {'Postal_District': 'PA29',
#   'Demand_P1': 2272,
#   'Demand_P2': 2111,
#   'Demand_P3': 8515,
#   'Demand_P4': 3928},
#  1773: {'Postal_District': 'PA30',
#   'Demand_P1': 2177,
#   'Demand_P2': 1483,
#   'Demand_P3': 18878,
#   'Demand_P4': 2212},
#  1774: {'Postal_District': 'PA31',
#   'Demand_P1': 3398,
#   'Demand_P2': 2043,
#   'Demand_P3': 17769,
#   'Demand_P4': 1889},
#  1775: {'Postal_District': 'PA32',
#   'Demand_P1': 1128,
#   'Demand_P2': 424,
#   'Demand_P3': 5186,
#   'Demand_P4': 174},
#  1776: {'Postal_District': 'PA33',
#   'Demand_P1': 632,
#   'Demand_P2': 216,
#   'Demand_P3': 2361,
#   'Demand_P4': 91},
#  1777: {'Postal_District': 'PA34',
#   'Demand_P1': 16209,
#   'Demand_P2': 5720,
#   'Demand_P3': 118053,
#   'Demand_P4': 7606},
#  1778: {'Postal_District': 'PA35',
#   'Demand_P1': 798,
#   'Demand_P2': 704,
#   'Demand_P3': 5313,
#   'Demand_P4': 877},
#  1779: {'Postal_District': 'PA36',
#   'Demand_P1': 22,
#   'Demand_P2': 20,
#   'Demand_P3': 89,
#   'Demand_P4': 13},
#  1780: {'Postal_District': 'PA37',
#   'Demand_P1': 2767,
#   'Demand_P2': 1953,
#   'Demand_P3': 12934,
#   'Demand_P4': 1385},
#  1781: {'Postal_District': 'PA38',
#   'Demand_P1': 1302,
#   'Demand_P2': 965,
#   'Demand_P3': 5579,
#   'Demand_P4': 878},
#  1783: {'Postal_District': 'PA41',
#   'Demand_P1': 126,
#   'Demand_P2': 179,
#   'Demand_P3': 1055,
#   'Demand_P4': 137},
#  1784: {'Postal_District': 'PA42',
#   'Demand_P1': 1054,
#   'Demand_P2': 331,
#   'Demand_P3': 3316,
#   'Demand_P4': 314},
#  1785: {'Postal_District': 'PA43',
#   'Demand_P1': 983,
#   'Demand_P2': 794,
#   'Demand_P3': 7947,
#   'Demand_P4': 1286},
#  1786: {'Postal_District': 'PA44',
#   'Demand_P1': 499,
#   'Demand_P2': 358,
#   'Demand_P3': 3532,
#   'Demand_P4': 282},
#  1787: {'Postal_District': 'PA45',
#   'Demand_P1': 198,
#   'Demand_P2': 133,
#   'Demand_P3': 1792,
#   'Demand_P4': 146},
#  1788: {'Postal_District': 'PA46',
#   'Demand_P1': 119,
#   'Demand_P2': 117,
#   'Demand_P3': 296,
#   'Demand_P4': 130},
#  1789: {'Postal_District': 'PA47',
#   'Demand_P1': 234,
#   'Demand_P2': 114,
#   'Demand_P3': 1463,
#   'Demand_P4': 73},
#  1790: {'Postal_District': 'PA48',
#   'Demand_P1': 163,
#   'Demand_P2': 150,
#   'Demand_P3': 624,
#   'Demand_P4': 152},
#  1791: {'Postal_District': 'PA49',
#   'Demand_P1': 98,
#   'Demand_P2': 182,
#   'Demand_P3': 638,
#   'Demand_P4': 255},
#  1794: {'Postal_District': 'PA60',
#   'Demand_P1': 325,
#   'Demand_P2': 232,
#   'Demand_P3': 1880,
#   'Demand_P4': 184},
#  1795: {'Postal_District': 'PA61',
#   'Demand_P1': 203,
#   'Demand_P2': 195,
#   'Demand_P3': 1076,
#   'Demand_P4': 377},
#  1796: {'Postal_District': 'PA62',
#   'Demand_P1': 11,
#   'Demand_P2': 15,
#   'Demand_P3': 33,
#   'Demand_P4': 10},
#  1797: {'Postal_District': 'PA63',
#   'Demand_P1': 4,
#   'Demand_P2': 3,
#   'Demand_P3': 21,
#   'Demand_P4': 2},
#  1798: {'Postal_District': 'PA64',
#   'Demand_P1': 49,
#   'Demand_P2': 60,
#   'Demand_P3': 268,
#   'Demand_P4': 61},
#  1799: {'Postal_District': 'PA65',
#   'Demand_P1': 329,
#   'Demand_P2': 150,
#   'Demand_P3': 1222,
#   'Demand_P4': 94},
#  1800: {'Postal_District': 'PA66',
#   'Demand_P1': 248,
#   'Demand_P2': 150,
#   'Demand_P3': 1420,
#   'Demand_P4': 299},
#  1801: {'Postal_District': 'PA67',
#   'Demand_P1': 378,
#   'Demand_P2': 181,
#   'Demand_P3': 2417,
#   'Demand_P4': 144},
#  1802: {'Postal_District': 'PA68',
#   'Demand_P1': 22,
#   'Demand_P2': 11,
#   'Demand_P3': 128,
#   'Demand_P4': 22},
#  1803: {'Postal_District': 'PA69',
#   'Demand_P1': 20,
#   'Demand_P2': 21,
#   'Demand_P3': 65,
#   'Demand_P4': 13},
#  1805: {'Postal_District': 'PA70',
#   'Demand_P1': 82,
#   'Demand_P2': 45,
#   'Demand_P3': 658,
#   'Demand_P4': 85},
#  1806: {'Postal_District': 'PA71',
#   'Demand_P1': 47,
#   'Demand_P2': 38,
#   'Demand_P3': 194,
#   'Demand_P4': 48},
#  1807: {'Postal_District': 'PA72',
#   'Demand_P1': 551,
#   'Demand_P2': 285,
#   'Demand_P3': 3855,
#   'Demand_P4': 238},
#  1808: {'Postal_District': 'PA73',
#   'Demand_P1': 71,
#   'Demand_P2': 31,
#   'Demand_P3': 283,
#   'Demand_P4': 30},
#  1809: {'Postal_District': 'PA74',
#   'Demand_P1': 28,
#   'Demand_P2': 21,
#   'Demand_P3': 127,
#   'Demand_P4': 32},
#  1810: {'Postal_District': 'PA75',
#   'Demand_P1': 3211,
#   'Demand_P2': 1579,
#   'Demand_P3': 20859,
#   'Demand_P4': 3593},
#  1811: {'Postal_District': 'PA76',
#   'Demand_P1': 181,
#   'Demand_P2': 54,
#   'Demand_P3': 812,
#   'Demand_P4': 52},
#  1812: {'Postal_District': 'PA77',
#   'Demand_P1': 1002,
#   'Demand_P2': 400,
#   'Demand_P3': 3939,
#   'Demand_P4': 468},
#  1813: {'Postal_District': 'PA78',
#   'Demand_P1': 283,
#   'Demand_P2': 130,
#   'Demand_P3': 905,
#   'Demand_P4': 172},
#  1815: {'Postal_District': 'PA80',
#   'Demand_P1': 306,
#   'Demand_P2': 172,
#   'Demand_P3': 984,
#   'Demand_P4': 221},
#  1853: {'Postal_District': 'PH1',
#   'Demand_P1': 33489,
#   'Demand_P2': 18193,
#   'Demand_P3': 256389,
#   'Demand_P4': 20120},
#  1864: {'Postal_District': 'PH2',
#   'Demand_P1': 34274,
#   'Demand_P2': 17873,
#   'Demand_P3': 208180,
#   'Demand_P4': 18444},
#  1872: {'Postal_District': 'PH3',
#   'Demand_P1': 3819,
#   'Demand_P2': 4568,
#   'Demand_P3': 14408,
#   'Demand_P4': 3335},
#  1883: {'Postal_District': 'PH4',
#   'Demand_P1': 1558,
#   'Demand_P2': 837,
#   'Demand_P3': 13926,
#   'Demand_P4': 785},
#  1890: {'Postal_District': 'PH5',
#   'Demand_P1': 348,
#   'Demand_P2': 230,
#   'Demand_P3': 1320,
#   'Demand_P4': 147},
#  1892: {'Postal_District': 'PH6',
#   'Demand_P1': 2962,
#   'Demand_P2': 3407,
#   'Demand_P3': 16509,
#   'Demand_P4': 5776},
#  1893: {'Postal_District': 'PH7',
#   'Demand_P1': 6270,
#   'Demand_P2': 4754,
#   'Demand_P3': 14749,
#   'Demand_P4': 1915},
#  1894: {'Postal_District': 'PH8',
#   'Demand_P1': 2280,
#   'Demand_P2': 1408,
#   'Demand_P3': 12253,
#   'Demand_P4': 1481},
#  1895: {'Postal_District': 'PH9',
#   'Demand_P1': 603,
#   'Demand_P2': 684,
#   'Demand_P3': 2830,
#   'Demand_P4': 465},
#  1854: {'Postal_District': 'PH10',
#   'Demand_P1': 8799,
#   'Demand_P2': 6454,
#   'Demand_P3': 36735,
#   'Demand_P4': 5254},
#  1855: {'Postal_District': 'PH11',
#   'Demand_P1': 4358,
#   'Demand_P2': 4081,
#   'Demand_P3': 33145,
#   'Demand_P4': 6129},
#  1856: {'Postal_District': 'PH12',
#   'Demand_P1': 2669,
#   'Demand_P2': 2129,
#   'Demand_P3': 22535,
#   'Demand_P4': 1562},
#  1857: {'Postal_District': 'PH13',
#   'Demand_P1': 1322,
#   'Demand_P2': 1197,
#   'Demand_P3': 6018,
#   'Demand_P4': 995},
#  1858: {'Postal_District': 'PH14',
#   'Demand_P1': 1645,
#   'Demand_P2': 904,
#   'Demand_P3': 12110,
#   'Demand_P4': 1898},
#  1859: {'Postal_District': 'PH15',
#   'Demand_P1': 2816,
#   'Demand_P2': 1707,
#   'Demand_P3': 21191,
#   'Demand_P4': 2366},
#  1860: {'Postal_District': 'PH16',
#   'Demand_P1': 2963,
#   'Demand_P2': 1540,
#   'Demand_P3': 5398,
#   'Demand_P4': 849},
#  1861: {'Postal_District': 'PH17',
#   'Demand_P1': 119,
#   'Demand_P2': 86,
#   'Demand_P3': 598,
#   'Demand_P4': 88},
#  1862: {'Postal_District': 'PH18',
#   'Demand_P1': 1392,
#   'Demand_P2': 464,
#   'Demand_P3': 8111,
#   'Demand_P4': 607},
#  1863: {'Postal_District': 'PH19',
#   'Demand_P1': 93,
#   'Demand_P2': 100,
#   'Demand_P3': 574,
#   'Demand_P4': 102},
#  1865: {'Postal_District': 'PH20',
#   'Demand_P1': 739,
#   'Demand_P2': 667,
#   'Demand_P3': 2464,
#   'Demand_P4': 369},
#  1866: {'Postal_District': 'PH21',
#   'Demand_P1': 1447,
#   'Demand_P2': 726,
#   'Demand_P3': 6912,
#   'Demand_P4': 501},
#  1867: {'Postal_District': 'PH22',
#   'Demand_P1': 1234,
#   'Demand_P2': 2085,
#   'Demand_P3': 3011,
#   'Demand_P4': 1913},
#  1868: {'Postal_District': 'PH23',
#   'Demand_P1': 676,
#   'Demand_P2': 470,
#   'Demand_P3': 1102,
#   'Demand_P4': 266},
#  1869: {'Postal_District': 'PH24',
#   'Demand_P1': 664,
#   'Demand_P2': 232,
#   'Demand_P3': 3058,
#   'Demand_P4': 236},
#  1870: {'Postal_District': 'PH25',
#   'Demand_P1': 703,
#   'Demand_P2': 490,
#   'Demand_P3': 1827,
#   'Demand_P4': 211},
#  1871: {'Postal_District': 'PH26',
#   'Demand_P1': 2172,
#   'Demand_P2': 3875,
#   'Demand_P3': 17398,
#   'Demand_P4': 2387},
#  1873: {'Postal_District': 'PH30',
#   'Demand_P1': 15,
#   'Demand_P2': 14,
#   'Demand_P3': 79,
#   'Demand_P4': 10},
#  1874: {'Postal_District': 'PH31',
#   'Demand_P1': 333,
#   'Demand_P2': 233,
#   'Demand_P3': 1085,
#   'Demand_P4': 173},
#  1875: {'Postal_District': 'PH32',
#   'Demand_P1': 587,
#   'Demand_P2': 930,
#   'Demand_P3': 3012,
#   'Demand_P4': 1013},
#  1876: {'Postal_District': 'PH33',
#   'Demand_P1': 9965,
#   'Demand_P2': 9815,
#   'Demand_P3': 53280,
#   'Demand_P4': 6258},
#  1877: {'Postal_District': 'PH34',
#   'Demand_P1': 985,
#   'Demand_P2': 592,
#   'Demand_P3': 5718,
#   'Demand_P4': 851},
#  1878: {'Postal_District': 'PH35',
#   'Demand_P1': 272,
#   'Demand_P2': 184,
#   'Demand_P3': 893,
#   'Demand_P4': 70},
#  1879: {'Postal_District': 'PH36',
#   'Demand_P1': 2184,
#   'Demand_P2': 1300,
#   'Demand_P3': 14649,
#   'Demand_P4': 2270},
#  1880: {'Postal_District': 'PH37',
#   'Demand_P1': 110,
#   'Demand_P2': 144,
#   'Demand_P3': 457,
#   'Demand_P4': 214},
#  1881: {'Postal_District': 'PH38',
#   'Demand_P1': 174,
#   'Demand_P2': 98,
#   'Demand_P3': 842,
#   'Demand_P4': 108},
#  1882: {'Postal_District': 'PH39',
#   'Demand_P1': 307,
#   'Demand_P2': 473,
#   'Demand_P3': 2676,
#   'Demand_P4': 335},
#  1884: {'Postal_District': 'PH40',
#   'Demand_P1': 308,
#   'Demand_P2': 152,
#   'Demand_P3': 946,
#   'Demand_P4': 59},
#  1885: {'Postal_District': 'PH41',
#   'Demand_P1': 2134,
#   'Demand_P2': 579,
#   'Demand_P3': 12461,
#   'Demand_P4': 450},
#  1886: {'Postal_District': 'PH42',
#   'Demand_P1': 130,
#   'Demand_P2': 88,
#   'Demand_P3': 644,
#   'Demand_P4': 156},
#  1887: {'Postal_District': 'PH43',
#   'Demand_P1': 46,
#   'Demand_P2': 23,
#   'Demand_P3': 212,
#   'Demand_P4': 34},
#  1888: {'Postal_District': 'PH44',
#   'Demand_P1': 0,
#   'Demand_P2': 0,
#   'Demand_P3': 0,
#   'Demand_P4': 0},
#  1889: {'Postal_District': 'PH49',
#   'Demand_P1': 708,
#   'Demand_P2': 377,
#   'Demand_P3': 2399,
#   'Demand_P4': 218},
#  1891: {'Postal_District': 'PH50',
#   'Demand_P1': 1102,
#   'Demand_P2': 395,
#   'Demand_P3': 6085,
#   'Demand_P4': 230},
#  2399: {'Postal_District': 'TD1',
#   'Demand_P1': 22512,
#   'Demand_P2': 8341,
#   'Demand_P3': 97359,
#   'Demand_P4': 5192},
#  2406: {'Postal_District': 'TD2',
#   'Demand_P1': 3518,
#   'Demand_P2': 1430,
#   'Demand_P3': 19624,
#   'Demand_P4': 1869},
#  2407: {'Postal_District': 'TD3',
#   'Demand_P1': 1424,
#   'Demand_P2': 344,
#   'Demand_P3': 4143,
#   'Demand_P4': 368},
#  2408: {'Postal_District': 'TD4',
#   'Demand_P1': 2766,
#   'Demand_P2': 750,
#   'Demand_P3': 8517,
#   'Demand_P4': 521},
#  2409: {'Postal_District': 'TD5',
#   'Demand_P1': 8359,
#   'Demand_P2': 4064,
#   'Demand_P3': 17758,
#   'Demand_P4': 2207},
#  2410: {'Postal_District': 'TD6',
#   'Demand_P1': 5044,
#   'Demand_P2': 7610,
#   'Demand_P3': 28814,
#   'Demand_P4': 8175},
#  2411: {'Postal_District': 'TD7',
#   'Demand_P1': 4511,
#   'Demand_P2': 3132,
#   'Demand_P3': 11478,
#   'Demand_P4': 1329},
#  2412: {'Postal_District': 'TD8',
#   'Demand_P1': 3151,
#   'Demand_P2': 1803,
#   'Demand_P3': 5727,
#   'Demand_P4': 1801},
#  2413: {'Postal_District': 'TD9',
#   'Demand_P1': 20439,
#   'Demand_P2': 14268,
#   'Demand_P3': 114151,
#   'Demand_P4': 14287},
#  2400: {'Postal_District': 'TD10',
#   'Demand_P1': 438,
#   'Demand_P2': 365,
#   'Demand_P3': 1492,
#   'Demand_P4': 136},
#  2401: {'Postal_District': 'TD11',
#   'Demand_P1': 4414,
#   'Demand_P2': 8121,
#   'Demand_P3': 29770,
#   'Demand_P4': 10677},
#  2402: {'Postal_District': 'TD12',
#   'Demand_P1': 5584,
#   'Demand_P2': 3149,
#   'Demand_P3': 29095,
#   'Demand_P4': 3830},
#  2403: {'Postal_District': 'TD13',
#   'Demand_P1': 461,
#   'Demand_P2': 442,
#   'Demand_P3': 2167,
#   'Demand_P4': 421},
#  2404: {'Postal_District': 'TD14',
#   'Demand_P1': 7770,
#   'Demand_P2': 3855,
#   'Demand_P3': 30520,
#   'Demand_P4': 4654},
#  2405: {'Postal_District': 'TD15',
#   'Demand_P1': 15300,
#   'Demand_P2': 27043,
#   'Demand_P3': 161297,
#   'Demand_P4': 59463}}

# %%
W[1]['X']
# Out:
# 392949

# %%
Pot_loc.head()
# Out:
#    ID   P_D P_A   Ref_PC       X       Y        C           Q
# 0   1  AB10  AB  AB106HA  392949  805109  3728000   9072000.0
# 1   2  AB11  AB  AB115QH  394404  805438  3664000   9156000.0
# 2   3  AB12  AB  AB123LL  393407  800946  3136000   9912000.0
# 3   4  AB13  AB  AB130EH  385705  801808  3096000   9996000.0
# 4   5  AB14  AB  AB140LA  383616  801140  2752000  10584000.0
